# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.
#
# # Observable Trends based on the data
#     # Cloudiness does not shows a correlation to latitude
#     # Average windspeed is 8.27, windspeed slighty increase from the equator
#     # Humidity does not have much correlation to latitude. Humidity is high at this time of the year
#     # Cities close to the equator has consistent temperature

# %%
#install citypy
# !pip install citipy

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
#output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
          

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#OpenWeatherMap API Key
api_key = api_keys.api_key

#city
#city= "London"

# Starting URL for Weather Map API Call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
url

# Get weather data
#weather_response = requests.get(url)
#weather_json = weather_response.json()
#print(weather_json)
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=271814c2941f62a3116c6e8bbc8a1536'

# %%
#run test for city
#for city in cities:
    #print (city)
    
# Create empty lists to append the API data into lists 
city_city = []
country = []
date= []
cloudiness = []
humidity = []
lng = []
lat = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")


#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_city.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# Processing Record 1 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=271814c2941f62a3116c6e8bbc8a1536&q=albany
# Processing Record 2 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=271814c2941f62a3116c6e8bbc8a1536&q=ushuaia
# Processing Record 3 | Ouango
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=271814c2941f62a3116c6e8bbc8a1536&q=ouango
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=271814c2941f62a3116c6e8bbc8a1536&q=vao
# Processing Record 5 | Bay Roberts
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=271814c2941f62a3116c6e8bbc8a1536&q=bay roberts
# City not found. Skipping...
# Processing Record 6 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=271814c2941f62a3116c6e8bbc8a1536&q=mataura
# ...

# %%
#create a dictionary with the list created:

dictionary= {
    "City": city_city,
    "Country": country,
    "Date": date,
    "Cloudiness": cloudiness,
    "Humidity": humidity,
    "Lng": lng,
    "Lat": lat,
    "Wind Speed": wind_speed,
    "Max Temp": max_temp
}
print (dictionary)
# Out:
# {'City': ['Albany', 'Ushuaia', 'Ouango', 'Vao', 'Bay Roberts', 'Mataura', 'Marawi', 'Esperance', 'Najran', 'Ottawa', 'Rikitea', 'Chuy', 'Tshela', 'San Quintin', 'Nabire', 'Atuona', 'Ca Mau', 'Arraial do Cabo', 'Severo-Kurilsk', 'Jamestown', 'Lorengau', 'Kaitangata', 'Herat', 'Luderitz', 'Temiscaming', 'Hermanus', 'Kapaa', 'Puerto Ayora', 'Villa Bruzual', 'Zyryanka', 'Key West', 'Ilulissat', 'Avarua', 'Kahuta', 'Lebu', 'San Patricio', 'Busselton', 'Sao Miguel do Araguaia', 'Baruun-Urt', 'Bilibino', 'Dzhebariki-Khaya', 'Peniche', 'Tuatapere', 'Chokurdakh', 'Bluff', 'Buarcos', 'Thinadhoo', 'Hualmay', 'Lasa', 'Lompoc', 'Punta Arenas', 'Poya', 'Hobart', 'Port-Gentil', 'Nikolskoye', 'Hithadhoo', 'Quatre Cocos', 'Khatanga', 'Comodoro Rivadavia', 'Port Alfred', 'Sur', 'Tasiilaq', 'Iquitos', 'Dunmore Town', 'Plouzane', 'Muros', 'New Norfolk', 'Saint-Georges', 'Beloha', 'Bredasdorp', 'Airai', 'Upernavik', 'Karasjok', 'Contamana', 'Pangody', 'Winneba', 'Bethel', 'Sambava', 'Sao Filipe', 'Padang
# ...

# %%
#create a data frame from dicitionary
df= pd.DataFrame(dictionary)
df.count()
# Out:
# City          536
# Country       536
# Date          536
# Cloudiness    536
# Humidity      536
# Lng           536
# Lat           536
# Wind Speed    536
# Max Temp      536
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Save Df to csv
df.to_csv('Resource/df_csv')

#show the df
df.head()
# Out:
#           City Country        Date  Cloudiness  Humidity    Lng    Lat  \
# 0       Albany      US  1563567289          75        52 -73.75  42.65
# 1      Ushuaia      AR  1563567289          40        60 -68.31 -54.81
# 2       Ouango      CD  1563567289         100        98  22.55   4.31
# 3          Vao      EE  1563567290          19        94  26.19  59.10
# 4  Bay Roberts      CA  1563567290          40        43 -53.28  47.58
#
#    Wind Speed  Max Temp
# 0        8.05     93.99
# 1       17.22     41.00
# 2        2.82     69.43
# 3        3.13     56.29
# 4       27.51     73.99

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# create a scatter plot lat vs temp plot
plt.scatter(df["Lat"], df["Max Temp"],  s=30, facecolors= "blue", marker= "o")

#add title and label
plt.grid(True)
plt.title( "Latitude vs Temperature Plot (07-19-2019)")
plt.xlabel("Latitude")
plt.ylabel( "Max Temperature")

#save plot
plt.savefig('Resource/Latitude.png')

#show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# create a scatter plot lat vs temp plot
plt.scatter(df["Lat"], df["Humidity"],  s=30, facecolors= "blue", marker= "o")

#add title and label
plt.grid(True)
plt.title( "Latitude vs Humidity Plot (07-19-2019)")
plt.xlabel("Latitude")
plt.ylabel( "Humidity")

#save plot
plt.savefig('Resource/Humidity.png')

#show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# create a scatter plot lat vs temp plot
plt.scatter(df["Lat"], df["Cloudiness"],  s=30, facecolors= "blue", marker= "o")

#add title and label
plt.grid(True)
plt.title( "Latitude vs Cloudiness Plot (07-19-2019)")
plt.xlabel("Latitude")
plt.ylabel( "Cloudiness")

#save plot
plt.savefig('Resource/Cloudiness.png')

#show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# create a scatter plot lat vs temp plot
plt.scatter(df["Lat"], df["Wind Speed"],  s=30, facecolors= "blue", marker= "o")

#add title and label
plt.grid(True)
plt.title( "Latitude vs Wind Speed Plot (07-19-2019)")
plt.xlabel("Latitude")
plt.ylabel( "Wind Speed")

#save plot
plt.savefig('Resource/Wind Speed.png')

#show plot
plt.show()
